# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
import pandas as pd


# IMPORT DATA AND MAKE FIRST COLUMN LABEL
data_train = pd.read_csv('input/isolet1+2+3+4.data', header=None)
data_test = pd.read_csv('input/isolet5.data', header=None)
data = data_train.append(data_test).reset_index().drop(columns=['index'])
data_label = data[617]
data = data.drop(columns = [617])
data.insert(0, 'label', data_label)
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-161-80d808ccd371> in <module>
#       3
#       4 # IMPORT DATA AND MAKE FIRST COLUMN LABEL
# ----> 5 data_train = pd.read_csv('isolet1+2+3+4.data', header=None)
#       6 data_test = pd.read_csv('isolet5.data', header=None)
#       7 data = data_train.append(data_test).reset_index().drop(columns=['index'])
#
# ...

# %%
data_train = data.sample(frac=0.01, random_state=1)
data_test = data.drop(data_test.index)

X_train = data_train.iloc[:,1:]
y_train = data_train.iloc[:,0]

X_test = data_test.iloc[:,1:]
y_test = data_test.iloc[:,0]

# %%
data_train
# Out:
#       label       0       1       2       3       4       5       6       7  \
# 4733    2.0 -0.1500  0.3812  0.3416  0.5292  0.4376 -0.2708 -0.3938 -0.4604
# 4677   24.0 -0.5968 -0.2016  0.0618  0.6872  0.6954  0.5308  0.0946 -0.1358
# 4286   23.0 -0.4498  0.0182  0.2982  0.9044  1.0000  0.7792  0.4530  0.4958
# 3052   19.0 -0.5532 -0.0212  0.0638  0.8368  0.9930  0.5816  0.4894  0.2978
# 3730   13.0 -0.9836 -0.5778 -0.3196 -0.0984  0.2500  0.2132  0.1886  0.3894
# ...     ...     ...     ...     ...     ...     ...     ...     ...     ...
# 2481   19.0 -0.7772 -0.1378  0.0322  0.5190  0.8300  0.7302  0.2434  0.1436
# 3293   18.0 -0.4490 -0.1248  0.1184  0.2156  0.5008  1.0000  0.9320  0.7730
# 5401   21.0 -0.1826  0.6640  0.5684  0.0872 -0.1702 -0.6266 -0.5394 -0.5186
# 2827   10.0 -0.4174  0.0734  0.4564  0.7088  0.4678 -0.0206 -0.0756 -0.4128
# 5899   25.0 -0.4964  0.2500  0.8586  1.0000  0.8080  0.7572  0.2790 -0.3550
#
# ...

# %%
#scaler = StandardScaler()
#pca = PCA()


#scaler.fit(X_train)
#X_train = pd.DataFrame(scaler.transform(X_train))
#X_test = pd.DataFrame(scaler.transform(X_test))

#pca.fit(X_train)
#X_train = pd.DataFrame(pca.transform(X_train))
#X_test = pd.DataFrame(pca.transform(X_test))

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(max_iter=1000)
lr.fit(X_train, y_train)
y_predict = lr.predict(X_test)
sum(y_predict == y_test) / len(y_test)
# Out:
# 0.5812760500160308

# %%
if lr.predict_proba(X_test).shape[1] > 2:
# Out:
# 26

# %%
probas = lr.predict_proba(X_test)
max_probas = probas.max(1) # max(1) gives max of each row
min_max_proba = max_probas.argmin() # gives index of min element
min_max_proba
# Out:
# 288

# %%
probas[288]
# Out:
# array([0.06189198, 0.00645334, 0.00825043, 0.00293227, 0.04460999,
#        0.01986773, 0.00033781, 0.03615809, 0.01676684, 0.02159907,
#        0.0851704 , 0.05020463, 0.03547568, 0.1123778 , 0.00711757,
#        0.00141952, 0.08880677, 0.04586757, 0.06139038, 0.00155124,
#        0.0083547 , 0.00318404, 0.11614383, 0.07916993, 0.07605475,
#        0.00884364])

# %%
max_probas[288]
# Out:
# 0.1161438259037374

# %%
probas[288].argmax()
# Out:
# 22

# %%
y_predict[288]
# Out:
# 23.0

# %%
# define bin_data to only the data that has label 1 or 2
bin_data = data[((data[617] == 1) | (data[617] == 2))]

# define label as being 0 or 1
bin_data.loc[:,617] = bin_data[617] - 1

label = bin_data.loc[:,617]
bin_data = bin_data.drop(columns=[617])

bin_data.insert(0, 'label', label)
bin_data = bin_data.reset_index().drop(columns=['index'])
label = label.reset_index().drop(columns=['index'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexing.py:576: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
df = pd.DataFrame(X)
df.insert(0, 'label', label)

df_train = df.sample(frac=0.01, random_state =0)
df_test = df.drop(df_train.index)

# %%
import matplotlib.pyplot as plt
plt.plot(np.cumsum(pca.explained_variance_ratio_))

# %%
sum(pca.explained_variance_ratio_)
# Out:
# 0.9885508601927234

# %%
df_train
# Out:
#      label          0          1          2         3          4         5  \
# 434    0.0  14.260745  -0.913809  -4.364366  1.404368  -1.165041 -9.895097
# 122    1.0   1.715088   7.756048   5.164347 -6.848755  30.511713 -4.763045
# 224    0.0  19.589349  14.865681   6.887020 -4.427661  -0.051839  0.799328
# 479    1.0  -5.556446   3.291908  -9.440944  3.534697  -1.720291 -1.177314
# 205    0.0  13.487216   6.161088  -1.080348  0.042479   3.133719 -3.674672
# 569    0.0  12.698813  10.214300  -0.176826  2.960043  -0.358288 -8.549142
# 432    0.0   3.517073   2.875028  -5.115286  0.062674   4.258809 -1.583833
# 526    1.0  -0.792412   6.162778   4.976465 -4.134496  -2.179651  4.611508
# 439    1.0  -6.711857   5.697777  -3.841351 -4.426696  17.430436 -0.179283
# 162    1.0   2.755589  13.658150  -3.803515  2.406632  -0.559400  8.215237
# 315    1.0  -0.046209   5.869936  -2.091751 -2.854206  -3.722489 -5.054568
# ...

# %%
# Out:
# 0.9158249158249159

# %%
# last column is label
label = data.iloc[:,617] 
# all columns before last are features 
features = data_train.iloc[:,:617]

# %%
data_train[data_]
# Out:
#          0       1       2       3       4       5       6       7       8    \
# 0    -0.4394 -0.0930  0.1718  0.4620  0.6226  0.4704  0.3578  0.0478 -0.1184
# 1    -0.4348 -0.1198  0.2474  0.4036  0.5026  0.6328  0.4948  0.0338 -0.0520
# 2    -0.2330  0.2124  0.5014  0.5222 -0.3422 -0.5840 -0.7168 -0.6342 -0.8614
# 3    -0.3808 -0.0096  0.2602  0.2554 -0.4290 -0.6746 -0.6868 -0.6650 -0.8410
# 4    -0.3412  0.0946  0.6082  0.6216 -0.1622 -0.3784 -0.4324 -0.4358 -0.4966
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 6233 -0.5742  0.1050  0.4936  0.3986 -0.2058 -0.4130 -0.4188 -0.5194 -0.5080
# 6234 -0.4520  0.0154  0.5078  0.8978  0.7956  0.4366  0.2352  0.1300  0.0682
# 6235 -0.5824 -0.1646  0.1406  0.6224  0.6626  0.3172  0.0924  0.0120 -0.1646
# 6236  0.0160  0.8168  1.0000  0.7814  0.4084  0.2122 -0.2218 -0.6848 -0.8424
# 6237 -0.6116 -0.1040  0.2566  0.2316 -0.0568 -0.3648 -0.3870 -0.4868 -0.4674
#
# ...
